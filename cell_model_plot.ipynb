# %%
import numpy as np
import glob
import os
import matplotlib.pyplot as plt



from mpl_toolkits.mplot3d import Axes3D  # noqa: F401 unused import


import matplotlib.pyplot as plt
import numpy as np

# %%
files=glob.glob("CPD/prof_T*.txt")

# %%
nums=[]
for f in files:
    nums.append(int(f.split("T_")[1].split("_")[0]))
    
files =np.array(files)[np.argsort(nums)]

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ims = []
f=files[-1]

arr = np.loadtxt(f,delimiter=", ")


n = 100

# For each set of style and range settings, plot n random points in the box
# defined by x in [23, 32], y in [0, 100], z in [zlow, zhigh].
#for m in arr:
#    ax.scatter(*m[1:4],s= (m[4])**2,cmap='viridis')
x=arr[:,1].flatten()
y= arr[:,2].flatten()
z=arr[:,3].flatten()

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')
ax.set_xlim([0,90])
ax.set_ylim([0,1000])

ax.set_zlim([0,400])

x=x[z>0]
y=y[z>0]
c=arr[:,5][z>0]
z= z[z>0]
ax.set_zlim([0,700])
im = ax.scatter(x, y, z,c=c, s=4,
                vmin=np.min(c),vmax=np.max(c),cmap='viridis' );
plt.colorbar(im)
ax.view_init(0, 360)
print(f)
plt.show()
# Out:
# /Users/nikhilkrishnan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:28: RuntimeWarning: invalid value encountered in greater
# /Users/nikhilkrishnan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:29: RuntimeWarning: invalid value encountered in greater
# /Users/nikhilkrishnan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:30: RuntimeWarning: invalid value encountered in greater
# /Users/nikhilkrishnan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:31: RuntimeWarning: invalid value encountered in greater
# CPD/prof_T_0_2020-09-21-17-59-44.txt

# %%
x=arr[:,1].flatten()
y= arr[:,2].flatten()
z=arr[:,3].flatten()
z
# Out:
# array([         nan,          nan,          nan, ..., 481.85542443,
#        177.43882339, 144.68654316])

# %%
fig = plt.figure(figsize=(12,6))
ax = fig.add_subplot(111, projection='3d')

ims = []
f=files[-1]

arr = np.loadtxt(f,delimiter=", ")


n = 100

# For each set of style and range settings, plot n random points in the box
# defined by x in [23, 32], y in [0, 100], z in [zlow, zhigh].
#for m in arr:
#    ax.scatter(*m[1:4],s= (m[4])**2,cmap='viridis')
x=arr[:,1].flatten()
y= arr[:,2].flatten()
z=arr[:,3].flatten()

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')
ax.set_xlim([0,90])
ax.set_ylim([10,1000])
x=x[z>0]
y=y[z>0]
c=arr[:,6][z>0]
z= z[z>0]
ax.set_zlim([0,500])
im = ax.scatter(x, y, z,c=c, s=20,vmin=np.min(c),vmax=np.max(c),cmap='RdBu',alpha=.5
                );
plt.colorbar(im)
ax.view_init(0, 360)
print(f)
plt.show()
# Out:
# /Users/nikhilkrishnan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:25: RuntimeWarning: invalid value encountered in greater
# /Users/nikhilkrishnan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:26: RuntimeWarning: invalid value encountered in greater
# /Users/nikhilkrishnan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:27: RuntimeWarning: invalid value encountered in greater
# /Users/nikhilkrishnan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:28: RuntimeWarning: invalid value encountered in greater
# CPD/prof_T_0_2020-09-21-17-59-44.txt

# %%
c
# Out:
# array([-1.77033839,  0.        ,  0.        , ..., -0.        ,
#         0.        ,  1.42651733])

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ims = []
f=files[-1]

arr = np.loadtxt(f,delimiter=", ")


n = 100

# For each set of style and range settings, plot n random points in the box
# defined by x in [23, 32], y in [0, 100], z in [zlow, zhigh].
#for m in arr:
#    ax.scatter(*m[1:4],s= (m[4])**2,cmap='viridis')
x=arr[:,1].flatten()
y= arr[:,2].flatten()
z=arr[:,3].flatten()

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')
ax.set_xlim([0,90])
ax.set_ylim([0,800])
x=x[z>0]
y=y[z>0]
c=arr[:,7][z>0]
z= z[z>0]
ax.set_zlim
ax.set_zlim([0,600])
im = ax.scatter(x, y, z,c=c, s=4,vmin=np.min(c),vmax=np.max(c),cmap='coolwarm' );
plt.colorbar(im)
ax.view_init(-10, 350)
print(f)
plt.show()
# Out:
# CPD/prof_T_0_2020-09-21-11-30-09.txt

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ims = []
f=files[-1]

arr = np.loadtxt(f,delimiter=", ")


n = 100

# For each set of style and range settings, plot n random points in the box
# defined by x in [23, 32], y in [0, 100], z in [zlow, zhigh].
#for m in arr:
#    ax.scatter(*m[1:4],s= (m[4])**2,cmap='viridis')
x=arr[:,1].flatten()
y= arr[:,2].flatten()
z=arr[:,3].flatten()

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')
ax.set_xlim([0,90])
ax.set_ylim([0,800])

ax.set_zlim([0,200])


x=x[z>0]
y=y[z>0]
c = (np.sum(arr[:,5:]**2,axis=1)**.5)[z>0]
z= z[z>0]
im = ax.scatter(x, y, z,c=c, s=2,vmin=np.min(np.sum(arr[:,5:]**2,axis=1)**.5),vmax=np.max(np.sum(arr[:,5:]**2,axis=1)**.5),cmap='viridis' );
plt.colorbar(im)
ax.view_init(0, 360)
print(f)
plt.show()
# Out:
# /Users/nikhilkrishnan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:29: RuntimeWarning: invalid value encountered in greater
# /Users/nikhilkrishnan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:30: RuntimeWarning: invalid value encountered in greater
# /Users/nikhilkrishnan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:31: RuntimeWarning: invalid value encountered in greater
# /Users/nikhilkrishnan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:32: RuntimeWarning: invalid value encountered in greater
# CPD/prof_T_20_2020-09-21-11-30-09.txt

# %%
(np.sum(arr[:,5:]**2,axis=1)**.5)[z>0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-606-fa26d5b8630f> in <module>()
# ----> 1 (np.sum(arr[:,5:]**2,axis=1)**.5)[z>0]
#
# IndexError: boolean index did not match indexed array along dimension 0; dimension is 8640 but corresponding boolean dimension is 6224

# %%
fig = plt.figure(figsize=(20,2))
ax = fig.add_subplot(111, projection='3d')

ims = []
f=files[-1]

arr = np.loadtxt(f,delimiter=", ")


n = 100

# For each set of style and range settings, plot n random points in the box
# defined by x in [23, 32], y in [0, 100], z in [zlow, zhigh].
#for m in arr:
#    ax.scatter(*m[1:4],s= (m[4])**2,cmap='viridis')
x=arr[:,1].flatten()
y= arr[:,2].flatten()


z=arr[:,3].flatten()

x=x[z>0]
y=y[z>0]
z= z[z>0]



ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')
ax.set_xlim([0,90])
ax.set_ylim([0,1200])

ax.set_zlim([0,240])
im = ax.scatter(x, y, z,c=z, s=50,vmin=np.max(z[~np.isnan(z)])/2,vmax=np.max(z[~np.isnan(z)])
               );
plt.colorbar(im)
ax.view_init(90, 360)

print(f)
plt.show()
# Out:
# /Users/nikhilkrishnan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:22: RuntimeWarning: invalid value encountered in greater
# /Users/nikhilkrishnan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:23: RuntimeWarning: invalid value encountered in greater
# /Users/nikhilkrishnan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:24: RuntimeWarning: invalid value encountered in greater
# CPD/prof_T_30_2020-09-21-11-30-09.txt

# %%
np.max(z[~np.isnan(z)])
# Out:
# 199.93362584189

# %%
np.sum(arr[:,5:]**2,axis=1)**.5
# Out:
# array([6.50634233e-07, 6.14439481e-07, 6.71108764e-07, ...,
#        2.00934088e-07, 1.94536196e-07, 1.27786258e-07])

# %%
np.sum(arr[:,5:]**2,axis=1)
# Out:
# array([5.85280878e-14, 5.20591688e-14, 5.20591688e-14, ...,
#        5.50286644e-14, 5.50286644e-14, 6.13871702e-14])

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ims = []
f=files[-1]

arr = np.loadtxt(f,delimiter=", ")


n = 100

# For each set of style and range settings, plot n random points in the box
# defined by x in [23, 32], y in [0, 100], z in [zlow, zhigh].
#for m in arr:
#    ax.scatter(*m[1:4],s= (m[4])**2,cmap='viridis')
x=arr[:,1].flatten()
y= arr[:,2].flatten()
z=arr[:,3].flatten()

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')
ax.set_xlim([0,90])
ax.set_ylim([0,720])

ax.set_zlim([0,260])
ax.scatter(x, y, z,c=z, s=4.25**2);

for angle in range(0, 360):
    ax.view_init(0, angle)

plt.show()
