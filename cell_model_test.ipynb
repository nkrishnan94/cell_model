# %%
import numpy as np
import glob
import os
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401 unused import
import matplotlib.pyplot as plt
import numpy as np

# %%
filesy=glob.glob("CPD_yonly_attr/prof_T*.txt")
filesx=glob.glob("CPD_xonly_attr/prof_T*.txt")
filesz=glob.glob("CPD_zonly_attr/prof_T*.txt")

# %%
nums=[]
for f in filesy:
    nums.append(int(f.split("T_")[1].split("_")[0]))
    
filesy =np.array(filesy)[np.argsort(nums)]


nums=[]
for f in filesx:
    nums.append(int(f.split("T_")[1].split("_")[0]))
    
filesx =np.array(filesx)[np.argsort(nums)]


nums=[]
for f in filesz:
    nums.append(int(f.split("T_")[1].split("_")[0]))
    
filesz =np.array(filesz)[np.argsort(nums)]

# %%
filesz
# Out:
# array(['CPD_zonly_attr/prof_T_0_2020-10-12-10-14-08.txt',
#        'CPD_zonly_attr/prof_T_10_2020-10-12-10-14-08.txt',
#        'CPD_zonly_attr/prof_T_20_2020-10-12-10-14-08.txt',
#        'CPD_zonly_attr/prof_T_30_2020-10-12-10-14-08.txt',
#        'CPD_zonly_attr/prof_T_40_2020-10-12-10-14-08.txt',
#        'CPD_zonly_attr/prof_T_50_2020-10-12-10-14-08.txt',
#        'CPD_zonly_attr/prof_T_60_2020-10-12-10-14-08.txt',
#        'CPD_zonly_attr/prof_T_70_2020-10-12-10-14-08.txt',
#        'CPD_zonly_attr/prof_T_80_2020-10-12-10-14-08.txt',
#        'CPD_zonly_attr/prof_T_90_2020-10-12-10-14-08.txt',
#        'CPD_zonly_attr/prof_T_100_2020-10-12-10-14-08.txt',
#        'CPD_zonly_attr/prof_T_110_2020-10-12-10-14-08.txt',
#        'CPD_zonly_attr/prof_T_120_2020-10-12-10-14-08.txt',
#        'CPD_zonly_attr/prof_T_130_2020-10-12-10-14-08.txt',
#        'CPD_zonly_attr/prof_T_140_2020-10-12-10-14-08.txt',
#        'CPD_zonly_attr/prof_T_150_2020-10-12-10-14-08.txt',
# ...

# %%
ydists = []
for f in filesy:
    arr = np.loadtxt(f,delimiter=", ")
    

    ydists.append(arr[:,2])
    
    
xdists = []
for f in filesx:
    arr = np.loadtxt(f,delimiter=", ")
    

    xdists.append(arr[:,1])

    
zdists = []
for f in filesz:
    arr = np.loadtxt(f,delimiter=", ")
    

    zdists.append(arr[:,3])

# %%
fig,ax=plt.subplots()
a=2.5
R=4.125
ax.plot(np.abs(np.array(ydists)[:,0]/(a*R)-np.array(ydists)[:,1]/(a*R)))
ax.plot(np.abs(np.array(xdists)[:,0]/(a*R)-np.array(xdists)[:,1]/(a*R)))
ax.plot(np.abs(np.array(zdists)[:,0]/(a*R)-np.array(zdists)[:,1]/(a*R)))

ax.set_xlabel('Time steps',fontsize=14)
ax.set_ylabel('Y coord. (in outer radii)',fontsize=14)

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# %%
filesy=glob.glob("CPD_yonly_repel/prof_T*.txt")
filesx=glob.glob("CPD_xonly_repel/prof_T*.txt")
filesz=glob.glob("CPD_zonly_repel/prof_T*.txt")

# %%
nums=[]
for f in filesy:
    nums.append(int(f.split("T_")[1].split("_")[0]))
    
filesy =np.array(filesy)[np.argsort(nums)]




nums=[]
for f in filesx:
    nums.append(int(f.split("T_")[1].split("_")[0]))
    
filesx =np.array(filesx)[np.argsort(nums)]

nums=[]
for f in filesz:
    nums.append(int(f.split("T_")[1].split("_")[0]))
    
filesz =np.array(filesz)[np.argsort(nums)]

# %%
ydists = []
for f in filesy:
    arr = np.loadtxt(f,delimiter=", ")
    

    ydists.append(arr[:,2])
    
    
    
xdists = []
for f in filesx:
    arr = np.loadtxt(f,delimiter=", ")
    

    xdists.append(arr[:,1])
    
    
zdists = []
for f in filesz:
    arr = np.loadtxt(f,delimiter=", ")
    

    zdists.append(arr[:,3])

# %%
fig,ax=plt.subplots()
a=2.5
R=4.125
ax.plot(np.abs(np.array(ydists)[:,0]/(a*R)-np.array(ydists)[:,1]/(a*R)))
ax.plot(np.abs(np.array(xdists)[:,0]/(a*R)-np.array(xdists)[:,1]/(a*R)))
ax.plot(np.abs(np.array(zdists)[:,0]/(a*R)-np.array(zdists)[:,1]/(a*R)))
ax.set_xlabel('Time steps',fontsize=14)
ax.set_ylabel('Y coord. (in outer radii)',fontsize=14)

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# %%
files=glob.glob("CPD_3attr/prof_T*.txt")

# %%
nums=[]
for f in files:
    nums.append(int(f.split("T_")[1].split("_")[0]))
    
files =np.array(files)[np.argsort(nums)]

# %%
ycoor = []
for f in files:
    arr = np.loadtxt(f,delimiter=", ")
    

    ycoor.append(arr[:,2])
zcoor = []
for f in files:
    arr = np.loadtxt(f,delimiter=", ")
    

    zcoor.append(arr[:,3])

# %%
import matplotlib
fig,ax=plt.subplots()
cmap = matplotlib.cm.get_cmap('viridis')

rgba = cmap(0.5)

times = len(ycoor)
cs=np.arange(times)
norm = matplotlib.colors.Normalize(vmin=0, vmax=1000)
im = ax.scatter(np.array(ycoor[:130])/(a*R),np.array(zcoor[:130])/(a*R),c=np.repeat(cs[:130],3),
           vmin=0,vmax=np.max(cs[:30]),cmap='viridis',marker ='v')
ax.set_xlabel('Y coord. (in outer radii)',fontsize=14)
ax.set_ylabel('Z coord. (in outer radii)',fontsize=14)
    
plt.colorbar(im) 
for axis in ['top','bottom','left','right']:
  ax.spines[axis].set_linewidth(3)
ax.tick_params(axis='both', which='major', labelsize=16)

# %%
files=glob.glob("CPD_3repel/prof_T*.txt")
nums=[]
for f in files:
    nums.append(int(f.split("T_")[1].split("_")[0]))
    
files =np.array(files)[np.argsort(nums)]


ycoor = []
for f in files:
    arr = np.loadtxt(f,delimiter=", ")
    

    ycoor.append(arr[:,2])
zcoor = []
for f in files:
    arr = np.loadtxt(f,delimiter=", ")
    

    zcoor.append(arr[:,3])

# %%
import matplotlib
fig,ax=plt.subplots()
cmap = matplotlib.cm.get_cmap('viridis')

rgba = cmap(0.5)

times = len(ycoor)
cs=np.arange(times)
norm = matplotlib.colors.Normalize(vmin=0, vmax=1000)
im = ax.scatter(np.array(ycoor[:130])/(a*R),np.array(zcoor[:130])/(a*R),c=np.repeat(cs[:130],3),
           vmin=0,vmax=np.max(cs[:30]),cmap='viridis',marker ='^')
ax.set_xlabel('Y coord. (in outer radii)',fontsize=14)
ax.set_ylabel('Z coord. (in outer radii)',fontsize=14)
    
plt.colorbar(im) 
for axis in ['top','bottom','left','right']:
  ax.spines[axis].set_linewidth(3)
ax.tick_params(axis='both', which='major', labelsize=16)

# %%
files=glob.glob("CPD_agarattr/prof_T*.txt")
nums=[]
for f in files:
    nums.append(int(f.split("T_")[1].split("_")[0]))
    
files =np.array(files)[np.argsort(nums)]

zcoor = []
for f in files:
    arr = np.loadtxt(f,delimiter=", ")
    
 
    zcoor.append(arr[3])

# %%
import matplotlib
fig,ax=plt.subplots()
cmap = matplotlib.cm.get_cmap('viridis')

rgba = cmap(0.5)

times = len(zcoor)
cs=np.arange(times)
norm = matplotlib.colors.Normalize(vmin=0, vmax=1000)
im = ax.scatter(np.array([[1]]*130),np.array(zcoor[:130])/(a*R),c=np.repeat(cs[:130],1),
           vmin=0,vmax=130,cmap='viridis',marker ='v')
ax.set_xlabel('Y coord. (in outer radii)',fontsize=14)
ax.set_ylabel('Z coord. (in outer radii)',fontsize=14)
    
plt.colorbar(im) 
for axis in ['top','bottom','left','right']:
  ax.spines[axis].set_linewidth(3)
ax.tick_params(axis='both', which='major', labelsize=16)

# %%
files=glob.glob("CPD_agarrepel/prof_T*.txt")
nums=[]
for f in files:
    nums.append(int(f.split("T_")[1].split("_")[0]))
    
files =np.array(files)[np.argsort(nums)]

zcoor = []
for f in files:
    arr = np.loadtxt(f,delimiter=", ")
    
 
    zcoor.append(arr[3])

# %%
import matplotlib
fig,ax=plt.subplots()
cmap = matplotlib.cm.get_cmap('viridis')

rgba = cmap(0.5)

times = len(zcoor)
cs=np.arange(times)
norm = matplotlib.colors.Normalize(vmin=0, vmax=1000)
im = ax.scatter(np.array([[1]]*130),np.array(zcoor[:130])/(a*R),c=np.repeat(cs[:130],1),
           vmin=0,vmax=130,cmap='viridis',marker ='v')
ax.set_xlabel('Y coord. (in outer radii)',fontsize=14)
ax.set_ylabel('Z coord. (in outer radii)',fontsize=14)
    
plt.colorbar(im) 
for axis in ['top','bottom','left','right']:
  ax.spines[axis].set_linewidth(3)
ax.tick_params(axis='both', which='major', labelsize=16)

# %%
files=glob.glob("CPD_compressedline/prof_T*.txt")
nums=[]
for f in files:
    nums.append(int(f.split("T_")[1].split("_")[0]))
    
files =np.array(files)[np.argsort(nums)]

ycoor = []
for f in files:
    arr = np.loadtxt(f,delimiter=", ")
    
 
    ycoor.append(arr[:,2])

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation

fig,ax=plt.subplots()
a=2.5
R=4.125
ims=[]
for y in ycoor[:120]:
    im = ax.scatter(np.array(y)/(a*R),10*[1],c=['k']*10)
    for axis in ['top','bottom','left','right']:
        ax.spines[axis].set_linewidth(3)
    ax.set_xlabel('Y coord. (in outer radii)',fontsize=14)
    ax.set_ylabel('Z coord. (in outer radii)',fontsize=14)
    ims.append([im])

    
    
    
ani = animation.ArtistAnimation(fig, ims, interval=50, blit=True,
                                repeat_delay=500)



ani.save('compressedline.gif', writer= 'imagemagick' , fps=30)

# %%
files=glob.glob("CPD_repelline/prof_T*.txt")
nums=[]
for f in files:
    nums.append(int(f.split("T_")[1].split("_")[0]))
    
files =np.array(files)[np.argsort(nums)]

ycoor = []
for f in files:
    arr = np.loadtxt(f,delimiter=", ")
    

    ycoor.append(arr[:,2])

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation

fig,ax=plt.subplots()

ims=[]
for y in ycoor[:120]:
    im = ax.scatter(np.array(y)/(a*R),10*[1],c=['k']*10)
    for axis in ['top','bottom','left','right']:
       ax.spines[axis].set_linewidth(3)
    ims.append([im])
    
    
    
ani = animation.ArtistAnimation(fig, ims, interval=50, blit=True,
                                repeat_delay=500)


ani.save('repelline.gif', writer= 'imagemagick' , fps=30)

# %%
files=glob.glob("CPD_line_BC/prof_T*.txt")
nums=[]
for f in files:
    nums.append(int(f.split("T_")[1].split("_")[0]))
    
files =np.array(files)[np.argsort(nums)]

ycoor = []
yforce=[]

for f in files:
    arr = np.loadtxt(f,delimiter=", ")
    

    ycoor.append(arr[:,2])
    yforce.append(arr[:,6])

# %%
yforce[-1]
# Out:
# array([ 1.258e-08, -5.000e-11, -6.000e-11,  2.000e-11,  1.000e-11,
#         1.000e-11, -1.500e-10, -1.500e-10,  1.296e-08])

# %%
plt.scatter(np.array(ycoor[-1])/(a*R),9*[1],c=np.array(yforce[-1]),)
plt.xlim([0,100/(a*R)])
# Out:
# (0.0, 9.696969696969697)

# %%
files=glob.glob("CPD_line_diff/prof_T*.txt")
nums=[]
for f in files:
    nums.append(int(f.split("T_")[1].split("_")[0]))
    
files =np.array(files)[np.argsort(nums)]

ycoor = []
zcoor = []
yforce=[]

for f in files:
    arr = np.loadtxt(f,delimiter=", ")
    

    ycoor.append(arr[:,2])
    zcoor.append(arr[:,3])
    yforce.append(arr[:,6])

# %%
yforce[-1]
# Out:
# array([ 1.e-11, -1.e-11,  1.e-11, -0.e+00, -0.e+00,  0.e+00, -0.e+00,
#         1.e-11, -1.e-11])

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation

fig,ax=plt.subplots()

ims=[]
for y,z,yf in zip(ycoor[:120],zcoor[:120],yforce[:120]):
    im = ax.scatter(np.array(y)/(a*R),np.array(z)/(a*R),c=np.abs(yf),cmap='viridis')
    ax.set_xlabel('Y coord. (in outer radii)',fontsize=14)
    ax.set_ylabel('Z coord. (in outer radii)',fontsize=14)
    for axis in ['top','bottom','left','right']:
        ax.spines[axis].set_linewidth(3)
    ims.append([im])
    
    
    
ani = animation.ArtistAnimation(fig, ims, interval=50, blit=True,
                                repeat_delay=500)


ani.save('repellinediff.gif', writer= 'imagemagick' , fps=30)

# %%
files=glob.glob("CPD_ylinediffagar/prof_T*.txt")
nums=[]
for f in files:
    nums.append(int(f.split("T_")[1].split("_")[0]))
    
files =np.array(files)[np.argsort(nums)]

ycoor = []
zcoor = []
yforce=[]

for f in files:
    arr = np.loadtxt(f,delimiter=", ")
    

    ycoor.append(arr[:,2])
    zcoor.append(arr[:,3])
    yforce.append(arr[:,6])

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation

fig,ax=plt.subplots()

ims=[]
for y,z,yf in zip(ycoor[:2000],zcoor[:2000],yforce[:2000]):
    im = ax.scatter(np.array(y)/(a*R),np.array(z)/(a*R),c=np.abs(yf),cmap='viridis')
    ax.set_xlabel('Y coord. (in outer radii)',fontsize=14)
    ax.set_ylabel('Z coord. (in outer radii)',fontsize=14)
    for axis in ['top','bottom','left','right']:
        ax.spines[axis].set_linewidth(3)
    ims.append([im])
    
    
    
ani = animation.ArtistAnimation(fig, ims, interval=50, blit=True,
                                repeat_delay=500)


ani.save('repellinediffagar.gif', writer= 'imagemagick' , fps=30)

# %%
files=glob.glob("CPD_exp1/prof_T*.txt")
nums=[]
for f in files:
    nums.append(int(f.split("T_")[1].split("_")[0]))
    
files =np.array(files)[np.argsort(nums)]

ycoor = []
zcoor = []
yforce=[]
zforce=[]

for f in files:
    arr = np.loadtxt(f,delimiter=", ")
    

    
    ycoor.append(arr[:,2])
    zcoor.append(arr[:,3])
    yforce.append(arr[:,6])
    zforce.append(arr[:,7])

# %%
len(ycoor)
# Out:
# 1200

# %%
t=1199
y = np.array(ycoor)[t][np.array(zcoor)[t]>0]
z = np.array(zcoor)[t][np.array(zcoor)[t]>0]
zf = np.array(zforce)[t][np.array(zcoor)[t]>0]

plt.scatter(y,z,c=zf,cmap='RdBu',edgecolor='k')

plt.colorbar()

# %%
files=glob.glob("CPD_exp2/prof_T*.txt")
nums=[]
for f in files:
    nums.append(int(f.split("T_")[1].split("_")[0]))
    
files =np.array(files)[np.argsort(nums)]

ycoor = []
zcoor = []
yforce=[]
zforce=[]
xforce=[]
for f in files:
    arr = np.loadtxt(f,delimiter=", ")
    
    

    
    
    ycoor.append(arr[:,2])
    zcoor.append(arr[:,3])
    yforce.append(arr[:,6])
    zforce.append(arr[:,7])
    xforce.append(arr[:,5])

# %%
fig,ax=plt.subplots(figsize=(20,12))
t = 1199
y = np.array(ycoor)[t][np.array(zcoor)[t]>0]
z = np.array(zcoor)[t][np.array(zcoor)[t]>0]
zf = np.array(zforce)[t][np.array(zcoor)[t]>0]
yf = np.array(yforce)[t][np.array(zcoor)[t]>0]
xf = np.array(xforce)[t][np.array(zcoor)[t]>0]

im = ax.scatter(y,z,c=yf,cmap='RdBu',edgecolor='k')

plt.colorbar(im)

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation

fig,ax=plt.subplots()
a=2.5
R=4.125
ims=[]
for t in range(len(ycoor)):
    y = np.array(ycoor)[t][np.array(zcoor)[t]>0]
    z = np.array(zcoor)[t][np.array(zcoor)[t]>0]
    zf = np.array(zforce)[t][np.array(zcoor)[t]>0]
    im = ax.scatter(np.array(y)/(a*R),np.array(z)/(a*R),c=zf,cmap='RdBu',edgecolor='k')
    ax.set_xlabel('Y coord. (in outer radii)',fontsize=14)
    ax.set_ylabel('Z coord. (in outer radii)',fontsize=14)
    for axis in ['top','bottom','left','right']:
        ax.spines[axis].set_linewidth(3)
    ims.append([im])
    
    
    
ani = animation.ArtistAnimation(fig, ims, interval=50, blit=True,
                                repeat_delay=500)


ani.save('exp2.gif', writer= 'imagemagick' , fps=30)

# %%
files=glob.glob("CPD_exp3/prof_T*.txt")
nums=[]
for f in files:
    nums.append(int(f.split("T_")[1].split("_")[0]))
    
files =np.array(files)[np.argsort(nums)]

ycoor = []
zcoor = []
yforce=[]
zforce=[]
xforce=[]
for f in files:
    arr = np.loadtxt(f,delimiter=", ")
    
    ycoor.append(arr[:,2])
    zcoor.append(arr[:,3])
    yforce.append(arr[:,6])
    zforce.append(arr[:,7])
    xforce.append(arr[:,5])

# %%
fig,ax=plt.subplots(figsize=(20,12))
t = 1119
y = np.array(ycoor)[t][np.array(zcoor)[t]>0]
z = np.array(zcoor)[t][np.array(zcoor)[t]>0]
zf = np.array(zforce)[t][np.array(zcoor)[t]>0]
yf = np.array(yforce)[t][np.array(zcoor)[t]>0]
xf = np.array(xforce)[t][np.array(zcoor)[t]>0]

im = ax.scatter(y,z,c=yf,cmap='RdBu',edgecolor='k')

plt.colorbar(im)

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation

fig,ax=plt.subplots()
a=2.5
R=4.125
ims=[]
for t in range(len(ycoor)):
    y = np.array(ycoor)[t][np.array(zcoor)[t]>0]
    z = np.array(zcoor)[t][np.array(zcoor)[t]>0]
    zf = np.array(zforce)[t][np.array(zcoor)[t]>0]
    im = ax.scatter(np.array(y)/(a*R),np.array(z)/(a*R),c=zf,cmap='RdBu',edgecolor='k')
    ax.set_xlabel('Y coord. (in outer radii)',fontsize=14)
    ax.set_ylabel('Z coord. (in outer radii)',fontsize=14)
    for axis in ['top','bottom','left','right']:
        ax.spines[axis].set_linewidth(3)
    ims.append([im])
    
    
    
ani = animation.ArtistAnimation(fig, ims, interval=50, blit=True,
                                repeat_delay=500)


ani.save('exp3.gif', writer= 'imagemagick' , fps=30)

# %%
files=glob.glob("CPD_exp4/prof_T*.txt")
nums=[]
for f in files:
    nums.append(int(f.split("T_")[1].split("_")[0]))
    
files =np.array(files)[np.argsort(nums)]

ycoor = []
zcoor = []
yforce=[]
zforce=[]
xforce=[]
for f in files:
    arr = np.loadtxt(f,delimiter=", ")
    
    ycoor.append(arr[:,2])
    zcoor.append(arr[:,3])
    yforce.append(arr[:,6])
    zforce.append(arr[:,7])
    xforce.append(arr[:,5])

# %%
fig,ax=plt.subplots(figsize=(20,12))
t = 1701
y = np.array(ycoor)[t][np.array(zcoor)[t]>0]
z = np.array(zcoor)[t][np.array(zcoor)[t]>0]
zf = np.array(zforce)[t][np.array(zcoor)[t]>0]
yf = np.array(yforce)[t][np.array(zcoor)[t]>0]
xf = np.array(xforce)[t][np.array(zcoor)[t]>0]

im = ax.scatter(y,z,c=yf,cmap='RdBu',edgecolor='k')

plt.colorbar(im)

# %%
files=glob.glob("CPD_exp5/prof_T*.txt")
nums=[]
for f in files:
    nums.append(int(f.split("T_")[1].split("_")[0]))
    
files =np.array(files)[np.argsort(nums)]

ycoor = []
zcoor = []
yforce=[]
zforce=[]
xforce=[]
for f in files:
    arr = np.loadtxt(f,delimiter=", ")
    
    ycoor.append(arr[:,2])
    zcoor.append(arr[:,3])
    yforce.append(arr[:,6])
    zforce.append(arr[:,7])
    xforce.append(arr[:,5])

# %%
len(ycoor)
# Out:
# 3511

# %%
fig,ax=plt.subplots(figsize=(20,12))
t = 3500

y = np.array(ycoor)[t][np.array(zcoor)[t]>0]
z = np.array(zcoor)[t][np.array(zcoor)[t]>0]
zf = np.array(zforce)[t][np.array(zcoor)[t]>0]
yf = np.array(yforce)[t][np.array(zcoor)[t]>0]
xf = np.array(xforce)[t][np.array(zcoor)[t]>0]

im = ax.scatter(y,z,c=zf,cmap='RdBu',edgecolor='k',s=100)

plt.colorbar(im)

# %%
files=glob.glob("CPD_exp6/prof_T*.txt")
nums=[]
for f in files:
    nums.append(int(f.split("T_")[1].split("_")[0]))
    
files =np.array(files)[np.argsort(nums)]

ycoor = []
zcoor = []
yforce=[]
zforce=[]
xforce=[]
for f in files:
    arr = np.loadtxt(f,delimiter=", ")
    
    ycoor.append(arr[:,2])
    zcoor.append(arr[:,3])
    yforce.append(arr[:,6])
    zforce.append(arr[:,7])
    xforce.append(arr[:,5])

# %%
fig,ax=plt.subplots(figsize=(20,12))
t = 2000

y = np.array(ycoor)[t][np.array(zcoor)[t]>0]
z = np.array(zcoor)[t][np.array(zcoor)[t]>0]
zf = np.array(zforce)[t][np.array(zcoor)[t]>0]
yf = np.array(yforce)[t][np.array(zcoor)[t]>0]
xf = np.array(xforce)[t][np.array(zcoor)[t]>0]

im = ax.scatter(y,z,c=zf,cmap='RdBu',edgecolor='k',s=100)

plt.colorbar(im)

# %%
files=glob.glob("CPD_exp7/prof_T*.txt")
nums=[]
for f in files:
    nums.append(int(f.split("T_")[1].split("_")[0]))
    
files =np.array(files)[np.argsort(nums)]

ycoor = []
zcoor = []
yforce=[]
zforce=[]
xforce=[]
for f in files:
    arr = np.loadtxt(f,delimiter=", ")
    
    ycoor.append(arr[:,2])
    zcoor.append(arr[:,3])
    yforce.append(arr[:,6])
    zforce.append(arr[:,7])
    xforce.append(arr[:,5])

# %%
fig,ax=plt.subplots(figsize=(20,12))
t = 350


y = np.array(ycoor)[t][np.array(zcoor)[t]>0]
z = np.array(zcoor)[t][np.array(zcoor)[t]>0]
zf = np.array(zforce)[t][np.array(zcoor)[t]>0]
yf = np.array(yforce)[t][np.array(zcoor)[t]>0]
xf = np.array(xforce)[t][np.array(zcoor)[t]>0]

im = ax.scatter(y,z,c=zf,cmap='RdBu',edgecolor='k',s=500)

plt.colorbar(im)

# %%
files=glob.glob("CPD_exp8/prof_T*.txt")
nums=[]
for f in files:
    nums.append(int(f.split("T_")[1].split("_")[0]))
    
files =np.array(files)[np.argsort(nums)]

ycoor = []
zcoor = []
yforce=[]
zforce=[]
xforce=[]
for f in files:
    arr = np.loadtxt(f,delimiter=", ")
    
    ycoor.append(arr[:,2])
    zcoor.append(arr[:,3])
    yforce.append(arr[:,6])
    zforce.append(arr[:,7])
    xforce.append(arr[:,5])

# %%
fig,ax=plt.subplots(figsize=(20,12))
t = len(yforce)-1


y = np.array(ycoor)[t][np.array(zcoor)[t]>0]
z = np.array(zcoor)[t][np.array(zcoor)[t]>0]
zf = np.array(zforce)[t][np.array(zcoor)[t]>0]
yf = np.array(yforce)[t][np.array(zcoor)[t]>0]
xf = np.array(xforce)[t][np.array(zcoor)[t]>0]

im = ax.scatter(y,z,c=yf,cmap='RdBu',edgecolor='k',s=500)

plt.colorbar(im)

# %%
files=glob.glob("CPD_exp9/prof_T*.txt")
nums=[]
for f in files:
    nums.append(int(f.split("T_")[1].split("_")[0]))
    
files =np.array(files)[np.argsort(nums)]

ycoor = []
zcoor = []
yforce=[]
zforce=[]
xforce=[]
for f in files:
    arr = np.loadtxt(f,delimiter=", ")
    
    ycoor.append(arr[:,2])
    zcoor.append(arr[:,3])
    yforce.append(arr[:,6])
    zforce.append(arr[:,7])
    xforce.append(arr[:,5])

# %%
fig,ax=plt.subplots(figsize=(20,12))
t = len(yforce)-100


y = np.array(ycoor)[t][np.array(zcoor)[t]>0]
z = np.array(zcoor)[t][np.array(zcoor)[t]>0]
zf = np.array(zforce)[t][np.array(zcoor)[t]>0]
yf = np.array(yforce)[t][np.array(zcoor)[t]>0]
xf = np.array(xforce)[t][np.array(zcoor)[t]>0]

im = ax.scatter(y,z,c=yf,cmap='RdBu',edgecolor='k',s=500)

plt.colorbar(im)

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation

fig,ax=plt.subplots()
a=2.5
R=4.125
ims=[]
for t in range(len(ycoor)):
    y = np.array(ycoor)[t][np.array(zcoor)[t]>0]
    z = np.array(zcoor)[t][np.array(zcoor)[t]>0]
    zf = np.array(zforce)[t][np.array(zcoor)[t]>0]
    im = ax.scatter(np.array(y)/(a*R),np.array(z)/(a*R),c=zf,cmap='RdBu',edgecolor='k')
    ax.set_xlabel('Y coord. (in outer radii)',fontsize=14)
    ax.set_ylabel('Z coord. (in outer radii)',fontsize=14)
    for axis in ['top','bottom','left','right']:
        ax.spines[axis].set_linewidth(3)
    ims.append([im])
    
    
    
ani = animation.ArtistAnimation(fig, ims, interval=50, blit=True,
                                repeat_delay=500)


ani.save('exp9.gif', writer= 'imagemagick' , fps=30)

# %%
files=glob.glob("CPD/prof_T*.txt")
nums=[]
for f in files:
    nums.append(int(f.split("T_")[1].split("_")[0]))
    
files =np.array(files)[np.argsort(nums)]

ycoor = []
zcoor = []
yforce=[]
zforce=[]
xforce=[]
for f in files:
    arr = np.loadtxt(f,delimiter=", ")
    
    ycoor.append(arr[:,2])
    zcoor.append(arr[:,3])
    yforce.append(arr[:,6])
    zforce.append(arr[:,7])
    xforce.append(arr[:,5])

# %%
np.max(np.array(yforce)[np.array(zcoor)>0])
# Out:
# 6.0249e-07

# %%
fig,ax=plt.subplots(figsize=(20,12))
t = len(yforce)
t=1000


y = np.array(ycoor)[t][np.array(zcoor)[t]>0]
z = np.array(zcoor)[t][np.array(zcoor)[t]>0]
zf = np.array(zforce)[t][np.array(zcoor)[t]>0]
yf = np.array(yforce)[t][np.array(zcoor)[t]>0]
xf = np.array(xforce)[t][np.array(zcoor)[t]>0]

im = ax.scatter(y,z,c=yf,cmap='RdBu',vmin=np.min(np.array(yforce)[np.array(zcoor)>0]),
                vmax=np.max(np.array(yforce)[np.array(zcoor)>0]),edgecolor='k',s=500)

plt.colorbar(im)

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation

fig,ax=plt.subplots()
a=2.5
R=4.125
ims=[]
for t in range(len(ycoor))[:1000][::3]:
    y = np.array(ycoor)[t][np.array(zcoor)[t]>0]
    z = np.array(zcoor)[t][np.array(zcoor)[t]>0]
    zf = np.array(zforce)[t][np.array(zcoor)[t]>0]
    im = ax.scatter(np.array(y)/(a*R),np.array(z)/(a*R),c=zf,cmap='RdBu',edgecolor='k',
                    vmin=np.min(np.array(yforce)[np.array(zcoor)>0]),
                vmax=np.max(np.array(yforce)[np.array(zcoor)>0]))
    ax.set_xlabel('Y coord. (in outer radii)',fontsize=14)
    ax.set_ylabel('Z coord. (in outer radii)',fontsize=14)
    for axis in ['top','bottom','left','right']:
        ax.spines[axis].set_linewidth(3)
    ims.append([im])
    
    
    
ani = animation.ArtistAnimation(fig, ims, interval=50, blit=True,
                                repeat_delay=500)


ani.save('exp10.gif', writer= 'imagemagick' , fps=30)

# %%
files=glob.glob("CPD/prof_T*.txt")
nums=[]

for f in files:
    nums.append(int(f.split("T_")[1].split("_")[0]))
    
files =np.array(files)[np.argsort(nums)]

ycoor = []
zcoor = []
yforce=[]
zforce=[]
xforce=[]
for f in files:
    arr = np.loadtxt(f,delimiter=", ")
    
    ycoor.append(arr[:,2])
    zcoor.append(arr[:,3])
    yforce.append(arr[:,6])
    zforce.append(arr[:,7])
    xforce.append(arr[:,5])

# %%
fig,ax=plt.subplots(figsize=(20,12))
t = len(yforce)
t=100






y = np.array(ycoor)[t][np.array(zcoor)[t]>0]
z = np.array(zcoor)[t][np.array(zcoor)[t]>0]
zf = np.array(zforce)[t][np.array(zcoor)[t]>0]
yf = np.array(yforce)[t][np.array(zcoor)[t]>0]
xf = np.array(xforce)[t][np.array(zcoor)[t]>0]

im = ax.scatter(y,z,c=yf,cmap='RdBu',vmin=np.min(np.array(yforce[t])[np.array(zcoor[t])>0]),
                vmax=np.max(np.array(yforce[t])[np.array(zcoor[t])>0]),edgecolor='k',s=500)

plt.colorbar(im)

# %%
fig = plt.figure(figsize=(20,12))
ax = fig.add_subplot(111, projection='3d')

ims = []
f=files2[8]
arr = np.loadtxt(f,delimiter=", ")


n = 100

# For each set of style and range settings, plot n random points in the box
# defined by x in [23, 32], y in [0, 100], z in [zlow, zhigh].
#for m in arr:
#    ax.scatter(*m[1:4],s= (m[4])**2,cmap='viridis')
x=arr[:,1].flatten()
y= arr[:,2].flatten()
z=arr[:,3].flatten()

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')
ax.set_xlim([0,90])
ax.set_ylim([0,1440])

ax.set_zlim([0,400])


x=x[z>0]
y=y[z>0]
c=arr[:,5][z>0]*10**6
z= z[z>0]
ax.set_zlim([0,700])
im = ax.scatter(x, y, z,c=c, s=4,
                vmin=np.min(c),vmax=np.max(c),cmap='viridis' );
plt.colorbar(im)
ax.view_init(0, 360)
print(f)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1157-f225542d04e0> in <module>
#       3
#       4 ims = []
# ----> 5 f=files2[8]
#       6 arr = np.loadtxt(f,delimiter=", ")
#       7
#
# NameError: name 'files2' is not defined

# %%
nums=[]
for f in files:
    nums.append(int(f.split("T_")[1].split("_")[0]))
    
files =np.array(files)[np.argsort(nums)]
for f in files:
    
    arr = np.loadtxt(f,delimiter=", ")



    z=arr[:,3].flatten()[(arr[:,2].flatten()>500) & (arr
                                                     [:,2].flatten()<1000)]
    

    print(np.max(z[~np.isnan(z)]))
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-1158-42f15e0de9a5> in <module>
#       6 for f in files:
#       7
# ----> 8     arr = np.loadtxt(f,delimiter=", ")
#       9
#      10
#
# ~/anaconda3/lib/python3.8/site-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows)
#     979             fname = os_fspath(fname)
#     980         if _is_string_like(fname):
# --> 981             fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#     982             fencoding = getattr(fh, 'encoding', 'latin1')
#     983             fh = iter(fh)
#
# ~/anaconda3/lib/python3.8/site-packages/numpy/lib/_datasource.py in open(path, mode, destpath, encoding, newline)
#     267
#     268     ds = DataSource(destpath)
# ...

# %%
arr[arr[:,2]>100,3][arr[:,2]<1000]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-2073-20672964dc09> in <module>
# ----> 1 arr[arr[:,2]>100,3][arr[:,2]<1000]
#
# IndexError: boolean index did not match indexed array along dimension 0; dimension is 18090 but corresponding boolean dimension is 19440

# %%
x=arr[:,1].flatten()
y= arr[:,2].flatten()
z=arr[:,3].flatten()
z

# %%
fig = plt.figure(figsize=(12,6))
ax = fig.add_subplot(111, projection='3d')

ims = []
f=files1[0]

arr = np.loadtxt(f,delimiter=", ")


n = 100

# For each set of style and range settings, plot n random points in the box
# defined by x in [23, 32], y in [0, 100], z in [zlow, zhigh].
#for m in arr:
#    ax.scatter(*m[1:4],s= (m[4])**2,cmap='viridis')
x=arr[:,1].flatten()
y= arr[:,2].flatten()
z=arr[:,3].flatten()

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')
ax.set_xlim([0,100])
ax.set_ylim([0,100])
x=x[z>0]
y=y[z>0]
c=arr[:,6][z>0]
z= z[z>0]
ax.set_zlim([0,100])
im = ax.scatter(x, y, z,c=c, s=20,vmin=np.min(c),vmax=np.max(c),cmap='RdBu',alpha=.5
                );
plt.colorbar(im)
ax.view_init(0, 360)
print(f)
plt.show()

# %%
arr[:,6]
# Out:
# array([ 5.7060e-08,  8.9039e-07, -1.6452e-06, ...,  1.9268e-07,
#         6.2484e-07,  4.9694e-07])

# %%
fig = plt.figure(figsize=(12,20))
ax = fig.add_subplot(111, projection='3d')

ims = []
f=files1[-1]

arr = np.loadtxt(f,delimiter=", ")


n = 100

# For each set of style and range settings, plot n random points in the box
# defined by x in [23, 32], y in [0, 100], z in [zlow, zhigh].
#for m in arr:
#    ax.scatter(*m[1:4],s= (m[4])**2,cmap='viridis')
x=arr[:,1].flatten()
y= arr[:,2].flatten()
z=arr[:,3].flatten()

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')
ax.set_xlim([0,90])
ax.set_ylim([0,1400])
x=x[z>0]
y=y[z>0]
c=arr[:,7][z>0]
z= z[z>0]
ax.set_zlim
ax.set_zlim([0,300])
im = ax.scatter(x, y, z,c=c, s=4,vmin=np.min(c),vmax=np.max(c),cmap='RdBu' );
plt.colorbar(im)
ax.view_init(0, 360)
print(f)
plt.show()
# Out:
# CPD/prof_T_9990_2020-10-11-20-11-01.txt

# %%
plt.hist(z)
# Out:
# (array([ 73., 101.,   0.,   0., 161.,   9.,   8.,  17., 298.,  41.]),
#  array([ 7.82349388, 10.23609532, 12.64869676, 15.06129821, 17.47389965,
#         19.88650109, 22.29910253, 24.71170398, 27.12430542, 29.53690686,
#         31.9495083 ]),
#  <a list of 10 Patch objects>)

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ims = []
f=files1[-1]

arr = np.loadtxt(f,delimiter=", ")


n = 100

# For each set of style and range settings, plot n random points in the box
# defined by x in [23, 32], y in [0, 100], z in [zlow, zhigh].
#for m in arr:
#    ax.scatter(*m[1:4],s= (m[4])**2,cmap='viridis')
x=arr[:,1].flatten()
y= arr[:,2].flatten()
z=arr[:,3].flatten()

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')
ax.set_xlim([0,100])
ax.set_ylim([0,100])

ax.set_zlim([0,100])


x=x[z>0]
y=y[z>0]
c = (np.sum(arr[:,5:]**2,axis=1)**.5)[z>0]
z= z[z>0]
im = ax.scatter(x, y, z,c=c, s=2,vmin=np.min(np.sum(arr[:,5:]**2,axis=1)**.5),vmax=np.max(np.sum(arr[:,5:]**2,axis=1)**.5),cmap='viridis' );
plt.colorbar(im)
ax.view_init(0, 360)
print(f)
plt.show()
# Out:
# CPD/prof_T_840_2020-10-11-19-58-04.txt

# %%
(np.sum(arr[:,5:]**2,axis=1)**.5)[z>0]
# Out:
# <ipython-input-1559-fa26d5b8630f>:1: RuntimeWarning: invalid value encountered in greater
#   (np.sum(arr[:,5:]**2,axis=1)**.5)[z>0]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-1559-fa26d5b8630f> in <module>
# ----> 1 (np.sum(arr[:,5:]**2,axis=1)**.5)[z>0]
#
# IndexError: boolean index did not match indexed array along dimension 0; dimension is 19440 but corresponding boolean dimension is 6885

# %%
fig = plt.figure(figsize=(20,2))
ax = fig.add_subplot(111, projection='3d')

ims = []
f=files1[1]

arr = np.loadtxt(f,delimiter=", ")


n = 100

# For each set of style and range settings, plot n random points in the box
# defined by x in [23, 32], y in [0, 100], z in [zlow, zhigh].
#for m in arr:
#    ax.scatter(*m[1:4],s= (m[4])**2,cmap='viridis')
x=arr[:,1].flatten()
y= arr[:,2].flatten()


z=arr[:,3].flatten()

x=x[z>0]
y=y[z>0]
z= z[z>0]



ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')
ax.set_xlim([0,90])
ax.set_ylim([0,1440])

ax.set_zlim([0,240])
im = ax.scatter(x, y, z,c=z, s=50,vmin=np.max(z[~np.isnan(z)])/2,vmax=130
               );
plt.colorbar(im)
ax.view_init(90, 360)

print(f)
plt.show()
# Out:
# CPD/prof_T_10_2020-10-11-16-56-48.txt

# %%
np.max(z[~np.isnan(z)])
# Out:
# 159.42566787258

# %%
np.sum(arr[:,5:]**2,axis=1)**.5
# Out:
# array([6.50634233e-07, 6.14439481e-07, 6.71108764e-07, ...,
#        2.00934088e-07, 1.94536196e-07, 1.27786258e-07])

# %%
np.sum(arr[:,5:]**2,axis=1)
# Out:
# array([5.85280878e-14, 5.20591688e-14, 5.20591688e-14, ...,
#        5.50286644e-14, 5.50286644e-14, 6.13871702e-14])

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ims = []
f=files[-1]

arr = np.loadtxt(f,delimiter=", ")


n = 100

# For each set of style and range settings, plot n random points in the box
# defined by x in [23, 32], y in [0, 100], z in [zlow, zhigh].
#for m in arr:
#    ax.scatter(*m[1:4],s= (m[4])**2,cmap='viridis')
x=arr[:,1].flatten()
y= arr[:,2].flatten()
z=arr[:,3].flatten()

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')
ax.set_xlim([0,90])
ax.set_ylim([0,720])

ax.set_zlim([0,260])
ax.scatter(x, y, z,c=z, s=4.25**2);

for angle in range(0, 360):
    ax.view_init(0, angle)

plt.show()

# %%
# !brew install imagemagick
# Out:
# Updating Homebrew...
# ==> Auto-updated Homebrew!
# Updated 3 taps (homebrew/cask-versions, homebrew/core and homebrew/cask).
# ==> New Formulae
# box2d                      libpciaccess               protoc-gen-go-grpc
# envoy                      matplotplusplus            tfsec
# ==> Updated Formulae
# Updated 103 formulae.
# ==> New Casks
# recaf
# ==> Updated Casks
# activedock                               nbtexplorer
# agenda                                   netron
# anydo                                    nextcloud
# arq5                                     openaudible
# browserosaurus                           opensesame
# catlight                                 outline-manager
# chromium                                 permute
# flutter                                  plotdigitizer
# foxitreader                              porting-kit
# freac                                    r
# gisto                                    rambox
# ...
